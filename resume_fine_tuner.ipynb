# %%
from ResumeFineTuner.ResumeFineTuner import ResumeFineTuner

# %%
job_description = """Sto gestendo una posizione per una figura di Team Leader per conto di una realtà finale ultra-innovativa, specializzata nello sviluppo di prodotti e soluzioni proprietarie nell'ambito data science, machine learning, math modeling development ed intelligenza artificiale.
"""
print(job_description)
# Out:
# Sto gestendo una posizione per una figura di Team Leader per conto di una realtà finale ultra-innovativa, specializzata nello sviluppo di prodotti e soluzioni proprietarie nell'ambito data science, machine learning, math modeling development ed intelligenza artificiale.

# %%
rft = ResumeFineTuner(job_description)
rft.fine_tune_cv()
# Out:
# ---------------------------------------------------
# PREPARING PROMPTS...
# ---------------------------------------------------
# You are a resume expert and you will write the section of a resume based on actual experience and tuned for the job description that the user asks.
# You will produce the following outputs:
# #PROFILE: high level presentation of candidate tuned for the job description (max 100 words).
# #MANAGER PROJECTS: select and rephrase main projects inherent for the job description among the manager ones (max 3 points).
# #SENIOR DATA SCIENTIST PROJECTS: select and rephrase main projects inherent for the job description among the senior data scientist ones (max 3 points).
# #RESEARCH FELLOW PROJECTS: select and rephrase main projects inherent for the job description among the research fellow ones (max 3 points).
# #KEY WORDS: key words related to actual experience and tuned for the job description (max 5 keywords).
#
# The candidate's actual experience is the following:
# profile:
# formation: PhD cum Laude in Nuclear and Energy Science and Engineering, Master degree in Nuclear Engineering
# known technical instruments: Python (Keras, Pytorch, Pandas, scikit-learn, OpenAI, HuggingFace, ...), C++, Matlab, Labview,
# experience with cloud providers: Google Cloud Platform, Amazon Web Service, Microsoft Azure
# experience: end-to-end AI systems development, junior resources management
#
# manager projects:
# * Custom ChatBot development, based on Large Language Models (OpenAI, HuggingFace), for a famous newspaper.
# * Anomaly detection for telecommunication industry using probabilistic recurrent neural networks.
# * HR advanced analytics for E&U society, classification of misused contracts using large language model.
# * Develop of an AI interface to semantically search and cluster laws from scraped websites.
#
# senior data scientist projects:
# * Self-supervised pattern extraction from customers of a trading platform, through multi-modal multi-task variational autoencoders.
# * Data Science guidelines definition (coding, MLOps, governance) for Energy & Utilities industry.
# * Long-term budget forecasting and industrialization on cloud (Google Cloud Platform) for Telco industry.
# * Generative AI projects developmenment, consisting in empowering articles with new content and reblending actual content in new forms, for a famous newspaper
# * Data pipeline implementation with Palantir Foundry platform in the field of Financial Services.
#
# research fellow projects:
# * Study of the laser-plasma interaction with numerical simulations and theoretical models.
# * Writing publications in peer-review international journals and presenting results in international conferences.
# * Carry out experiments of laser-plasma acceleration in collaboration with international facilities.
# * Presentation of results at international conferences.
# * Teach physics to first year engineering students.
# * Design and realization of nanostructured materials with advanced techniques.
#
#
#
# Note: Do not invet informations, just rephrase actual experience to meet the job description. Create the output in English.
#
# Here an example of the desired output:
# #PROFILE: [profile description]
#
# #MANAGER PROJECTS:
# * [manager project 1 description]
# * [manager project 2 description]
# * [manager project 3 description]
#
# #SENIOR DATA SCIENTIST PROJECTS:
# * [senior data scientist project 1 description]
# * [senior data scientist project 2 description]
# * [senior data scientist project 3 description]
#
# #RESEARCH FELLOW PROJECTS:
# * [research fellow project 1 description]
# * [research fellow project 2 description]
# * [research fellow project 3 description]
#
# #KEY WORDS:
# * [keyword 1]
# * [keyword 2]
# * [keyword 3]
# * [keyword 4]
# * [keyword 5]
#
#
# Write the candidate's resume in English for the following job description:
# Sto gestendo una posizione per una figura di Team Leader per conto di una realtà finale ultra-innovativa, specializzata nello sviluppo di prodotti e soluzioni proprietarie nell'ambito data science, machine learning, math modeling development ed intelligenza artificiale.
#
#
# ---------------------------------------------------
# GENERATING CV SECTIONS...
# ---------------------------------------------------
# #PROFILE:
# Highly skilled and innovative Team Leader with expertise in data science, machine learning, math modeling development, and artificial intelligence. Proven track record in developing proprietary products and solutions for cutting-edge organizations. Strong leadership abilities and a passion for driving teams towards success in an ultra-innovative environment.
#
# #MANAGER PROJECTS:
# * Developed a custom ChatBot utilizing Large Language Models (OpenAI, HuggingFace) for a renowned newspaper, enhancing user engagement and delivering personalized content.
# * Implemented anomaly detection using probabilistic recurrent neural networks for the telecommunication industry, significantly improving network security and minimizing downtime.
# * Led HR advanced analytics project for an Energy & Utilities society, leveraging large language models to classify misused contracts and mitigate legal risks.
#
# #SENIOR DATA SCIENTIST PROJECTS:
# * Utilized multi-modal multi-task variational autoencoders to extract self-supervised patterns from customers of a trading platform, enabling personalized recommendations and enhancing user experience.
# * Defined comprehensive data science guidelines (coding, MLOps, governance) for the Energy & Utilities industry, ensuring best practices and efficient collaboration across teams.
# * Led long-term budget forecasting and industrialization project on Google Cloud Platform for the Telco industry, optimizing resource allocation and driving cost savings.
#
# #RESEARCH FELLOW PROJECTS:
# * Conducted extensive numerical simulations and theoretical modeling to study laser-plasma interaction, contributing to advancements in laser-based technologies.
# * Published research findings in peer-reviewed international journals and presented results at prestigious conferences, showcasing expertise and building professional network.
# * Collaborated with international facilities to carry out experiments on laser-plasma acceleration, contributing to breakthroughs in particle physics.
#
# #KEY WORDS:
# * Data Science
# * Machine Learning
# * Math Modeling Development
# * Artificial Intelligence
# * Team Leadership
# ---------------------------------------------------
# OUTPUT GENERATED!
# ---------------------------------------------------
# ---------------------------------------------------
# PARSING OUTPUT...
# ---------------------------------------------------
# ---------------------------------------------------
# PARSED OUTPUT!
# ---------------------------------------------------
# {
#  "#PROFILE": "Highly skilled and innovative Team Leader with expertise in data science, machine learning, math modeling development, and artificial intelligence. Proven track record in developing proprietary products and solutions for cutting-edge organizations. Strong leadership abilities and a passion for driving teams towards success in an ultra-innovative environment.",
#  "#MANAGERPROJECTS1": "Developed a custom ChatBot utilizing Large Language Models (OpenAI, HuggingFace) for a renowned newspaper, enhancing user engagement and delivering personalized content.",
#  "#MANAGERPROJECTS2": "Implemented anomaly detection using probabilistic recurrent neural networks for the telecommunication industry, significantly improving network security and minimizing downtime.",
#  "#MANAGERPROJECTS3": "Led HR advanced analytics project for an Energy & Utilities society, leveraging large language models to classify misused contracts and mitigate legal risks.",
#  "#SENIORDATASCIENTISTPROJECTS1": "Utilized multi-modal multi-task variational autoencoders to extract self-supervised patterns from customers of a trading platform, enabling personalized recommendations and enhancing user experience.",
#  "#SENIORDATASCIENTISTPROJECTS2": "Defined comprehensive data science guidelines (coding, MLOps, governance) for the Energy & Utilities industry, ensuring best practices and efficient collaboration across teams.",
#  "#SENIORDATASCIENTISTPROJECTS3": "Led long-term budget forecasting and industrialization project on Google Cloud Platform for the Telco industry, optimizing resource allocation and driving cost savings.",
#  "#RESEARCHFELLOWPROJECTS1": "Conducted extensive numerical simulations and theoretical modeling to study laser-plasma interaction, contributing to advancements in laser-based technologies.",
#  "#RESEARCHFELLOWPROJECTS2": "Published research findings in peer-reviewed international journals and presented results at prestigious conferences, showcasing expertise and building professional network.",
#  "#RESEARCHFELLOWPROJECTS3": "Collaborated with international facilities to carry out experiments on laser-plasma acceleration, contributing to breakthroughs in particle physics.",
#  "#KEYWORDS1": "Data Science",
#  "#KEYWORDS2": "Machine Learning",
#  "#KEYWORDS3": "Math Modeling Development",
#  "#KEYWORDS4": "Artificial Intelligence",
#  "#KEYWORDS5": "Team Leadership"
# }
# ---------------------------------------------------
# UPDATING CV...
# ---------------------------------------------------
# ---------------------------------------------------
# CV UPDATED!
# ---------------------------------------------------
